# %%
import json
import re

with open('credentials.json') as file:
    credentials = json.load(file)

# %%
import requests
from datetime import datetime, timedelta

def get_sessions(session_type, req_from = 0):
    '''
    Returns all sessions based on sessiontype.
    '''

    url = "https://events.rainfocus.com/api/search"

    payload =   {
                    'search.sessiontype': session_type,
                    'type': 'session',
                    'catalogDisplay': 'list',
                    'browserTimezone': 'Europe%2FParis',
                    'from': req_from
                }

    headers = {
        'authority': 'events.rainfocus.com',
        'accept': '*/*',
        'accept-language': 'en-US,en;q=0.9,fr-FR;q=0.8,fr;q=0.7',
        'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'origin': 'https://www.ciscolive.com',
        'referer': 'https://www.ciscolive.com/',
        'rfapiprofileid': credentials['rfapiprofileid'],
        'rfauthtoken': credentials['rfauthtoken'],
        'rfwidgetid': credentials['rfwidgetid'],
    }

    response = requests.request("POST", url, headers=headers, data=payload)

    return response.json()

class Session():

    def __init__(self, session_json):
        self.type = session_json['type']
        try:
            self.start = datetime.strptime(session_json['times'][0]['utcStartTime'], '%Y/%m/%d %H:%M:%S') + timedelta(hours=1)
            self.end = datetime.strptime(session_json['times'][0]['utcEndTime'], '%Y/%m/%d %H:%M:%S') + timedelta(hours=1)
        except KeyError:
            self.start = 'Null'
            self.end = 'Null'
        self.day_name = session_json['times'][0]['dayName']
        self.name = re.sub(r"", "", session_json['title'])
        self.id = session_json['code']
        match int(self.id.split('-')[1][0]):
            case 1: self.level = 'Introductory'
            case 2: self.level = 'Intermediate'
            case 3: self.level = 'Advanced'
            case 4: self.level = 'General'
        self.capacity = int(session_json['times'][0]['capacity'])
        self.seats_remaining = int(session_json['times'][0]['seatsRemaining'])
        self.waitlist_remaining = int(session_json['times'][0]['waitlistRemaining'])
        self.room_id = session_json['times'][0]['roomId']
        self.room = session_json['times'][0]['room']
        
    def __str__(self):
        return self.name

# %%
if __name__ == '__main__':
    
    with open('credentials.json') as file:
        credentials = json.load(file)

    sessions = []
    session_types = ['Technical_seminar', 'BRK', 'Product-or-Strategy-Overview', 'Innovation_talk', 'Partner Session', 'DevNet', 'Walk-in Lab', 'Instructor Led Lab', 'Additional Programs']

    for session_type in session_types:

        full_sessions = 0
        
        sessions_json = get_sessions(session_type)

        req_from = int(sessions_json['sectionList'][0]['from'])
        num_items = int(sessions_json['sectionList'][0]['numItems'])
        total = int(sessions_json['sectionList'][0]['total'])
        size = int(sessions_json['sectionList'][0]['size'])

        while req_from + num_items < total:
            req_from += size
            sessions_json_temp = get_sessions(session_type, req_from=req_from)

            for session in sessions_json_temp['items']:
                sessions_json['sectionList'][0]['items'].append(session)


        for session in sessions_json['sectionList'][0]['items']:
            sessions.append(Session(session))

# %%
sessions_dict = {}

for session in sessions:
    sessions_dict[session.id] = session.name

# %%
import pandas as pd

df = pd.read_excel('french_customers_sessions.xlsx')

# %%
class Customer():

    def __init__(self, df_line) -> None:
        self.name = df_line.iloc[1] + ' ' + df_line.iloc[2]
        self.company = df_line.iloc[3]
        self.sessions = df_line.iloc[7].split(' | ')

# %%
customers = []

for index, row in df.iterrows():
    customers.append(Customer(row))

# %%
sessions_attended = []

for customer in customers:
    sessions_attended.extend(customer.sessions)

sessions_attended = list(set(sessions_attended))
print(sessions_attended)
# Out:
# ['BRKOPT-2837', 'BRKDCN-2938', 'BYODCRT-2464', 'BRKNWT-2210', 'BRKMER-2399', 'TECIPV-2265', 'BRKAPP-1154', 'TECSPG-2014', 'BRKMER-1752', 'BRKPAR-3569', 'BRKCCT-2724', 'BRKARC-2882', 'BRKSPG-2133', 'BRKTRS-2034', 'BRKSPG-2355', 'BRKOPT-2705', 'PSOCX-2113', 'DEVNET-2572', 'BRKCRT-2008', 'TECSPG-3204', 'DEVNET-2527', 'TSCSPG-2010', 'LTRCRT-2157', 'BRKSEC-2044', 'VR-1001', 'ADD-3127', 'DEVNET-1487', 'DEVNET-2628', 'BRKENT-3412', 'BRKOPT-1005', 'BRKOPS-2068', 'PSOIOT-1004', 'BRKSEC-3320', 'BRKOPS-2312', 'CSSSPG-2572', 'LABOPS-1507', 'DEVNET-1700', 'BRKSPG-2835', 'BRKOPT-2578', 'LTRMPL-2208', 'DEVNET-2094', 'CISCOU-2672', 'DEVWKS-1176', 'LTRMPL-2116', 'BRKSPG-2028', 'PSOSEC-1213', 'BRKDCN-3982', 'LTROPS-2835', 'DEVNET-2273', 'BRKSPG-3050', 'BRKSEC-3129', 'BRKSPG-2029', 'BRKPAR-3304', 'DEVWKS-2919', 'PSOMS-1330', 'BRKOPS-2431', 'BRKSEC-2051', 'BRKOPS-2176', 'TECSPG-2435', 'BRKOPS-2376', 'BRKDCN-1601', 'BRKSPG-3624', 'BRKSEC-2644', 'BRKPAR-2906', 'BRKSPG-2031', 'TECIPV-2000', 'LTRSEC-2272', 'BRKIPV-3340', 'DEVLIT-2785', 'DEVNET-2459', 'BRKDCN-2689', 'BRKDCN-1613', 'BRKOPS-2136', 'LTRSP-2837', 'BRKMPL-1123', 'BRKOPS-2040', 'BRKSEC-2128', 'BRKSEC-2678', 'BRKENT-2423', 'BRKSEC-2438', 'BRKDCN-2667', 'CSSSPG-1702', 'LTRSPG-2161', 'IMP-2741', 'BRKARC-2885', 'DEVWKS-2300', 'IBOSPG-2001', 'BRKDCN-2913', 'BRKDCN-2929', 'LTROPS-2409', 'BRKPAR-3078', 'BRKPAR-2911', 'TSCSPG-2011', 'BRKSPM-2024', 'ITLGEN-2103', 'BRKMPL-2131', 'LTRSP-3145', 'BRKDCN-2906', 'BRKOPS-2138', 'BRKENT-1616', 'LABTRS-2391', 'TSCTRS-2007', 'IBOOPT-2000', 'BRKSEC-2354', 'DEVWKS-2818', 'BRKSPG-2944', 'PSOCOL-2311', 'BRKDCN-2671', 'BRKOPT-2130', 'BRKSEC-1240', 'DEVNET-2084', 'BRKPAR-2965', 'BRKIOT-2585', 'CISCOU-2664', 'BRKTRS-2811', 'BRKCLD-2365', 'BRKDCN-1901', 'BRKSP-2551', 'BRKENT-2109', 'CISCOU-2666', 'BRKDCN-2621', 'DEVNET-1460', 'BRKIPV-3134', 'BRKENS-3096', 'PSOGEN-1040', 'DEVNET-1849', 'BRKAPP-1011', 'BRKSPG-2343', 'BRKDCN-3638', 'BRKSEC-3058', 'BRKSPG-2868', 'BRKDEV-1533', 'BRKENT-2060', 'DEVNET-2158', 'BRKSEC-2238', 'LTRIPV-2130', 'BRKDEV-2985', 'BRKSEC-2287', 'PSOSEC-1211', 'DEVNET-1850', 'BRKDCN-2999', 'BRKARC-2881', 'BRKSPG-2473', 'DEVNET-2405', 'CISCOU-2659', 'BRKIOT-2544', 'BRKDCN-2983', 'BRKOPT-2699', 'PSOENT-1794', 'BRKDCN-2924', 'BRKEWN-2284', 'BRKSEC-2172', 'BRKNWT-2205', 'ITLGEN-2213', 'TSCTRS-2004', 'BRKSP-2637', 'IBOCX-1101', 'LTRATO-2001', 'BRKSPM-2386', 'BRKSP-2133']

# %%
sessions_customers_dict = {}

for session in sessions_attended:
    sessions_customers_dict[session + ' - ' + sessions_dict.get(session, 'unknown')] = []

# %%
for customer in customers:
    for session in customer.sessions:
        sessions_customers_dict[session + ' - ' + sessions_dict.get(session, 'unknown')].append(customer.name + f' ({customer.company})')

# %%
sessions_customers_dict
# Out:
# {'BRKOPT-2837 - Scaling Enterprise Networks with Routed Optical Networking': ['Thomas Delaby (France-IX)'],
#  'BRKDCN-2938 - Intersight Managed Mode (IMM) for UCS Manager admins': ['Bastien Fine (Adista)'],
#  'BYODCRT-2464 - unknown': ['zakariaa FODIL (LINKT)'],
#  'BRKNWT-2210 - Predicting Networks are THERE !!': ['Mathieu Bonnin (Axione)',
#   'Frederic Faraux (Claranet)'],
#  'BRKMER-2399 - Meraki Wireless from a Troubleshooter Perspective': ['Stanislas de Goriainoff (SEWAN)'],
#  'TECIPV-2265 - IPv6 in your Network': ['Bastien Fine (Adista)',
#   'Thomas Delaby (France-IX)',
#   'Vittorio Mihailescu (France-IX)'],
#  'BRKAPP-1154 - Do Tell About OTel: An Introduction to OpenTelemetry and How AppDynamics is Embracing It': ['Pierre Etancelin (ALTITUDE INFRA)',
#   'Mathieu Bonnin (Axione)'],
#  'TECSPG-2014 - Cisco Converged SDN Transport': ['Jean-Michel Dilly (Adista)'],
#  'BRKMER-1752 - Experience the Journey to IPv6-Only With Cisco Meraki': ['Gilles Friang (SEWAN)',
#   'Stanislas de Goriainoff (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'BRKPAR-3569 - unknown': ['barnabe Louvet (LINKT)'],
#  'BRKCCT-2724 - Exploring Webex Contact Center functionality and use cases': ['Stanislas de Goriainoff (SEWAN)'],
#  'BRKARC-2882 - Cisco Catalyst 8200 / 8300 Series Access Edge Platforms Deep Dive': ['Jean-Paul Blaisonneau (Axione)'],
#  'BRKSPG-2133 - Evolution of the Transport Network Architecture in the Context of 5G and Open RAN ': ['Jean-Paul Blaisonneau (Axione)',
#   'Rodrigue ESTEVE (Axione)'],
#  'BRKTRS-2034 - Smart Licensing Troubleshooting and Case Studies': ['Bastien Fine (Adista)',
#   'Thomas Delaby (France-IX)'],
#  'BRKSPG-2355 - Trends & Topology Options for SP Networks - Adapting Webscale Technologies in the Provider Universe': ['Mathieu Bonnin (Axione)',
#   'Rodrigue ESTEVE (Axione)'],
#  'BRKOPT-2705 - Growing the Network with 400 Gbps Coherent Pluggable Optics': ['Jeremy Dassonville (ALTITUDE INFRA)',
#   'Mathieu Bonnin (Axione)',
#   'Romain CAMPOLI (Covage Infra)',
#   'Thomas Delaby (France-IX)'],
#  'PSOCX-2113 - Automate IT Management': ['wissal berrada (ALTITUDE INFRA)',
#   'Jérémy Pernes (ALTITUDE INFRA)',
#   'Frederic OSMONT (ALTITUDE INFRA)'],
#  'DEVNET-2572 - Implementing a Custom Compliance Using Python on Cisco NSO': ['Alexandre Bartoli (LINKT)'],
#  'BRKCRT-2008 - Earning Your CCNP Enterprise Certification: What You Need to  Know': ['Frederic OSMONT (ALTITUDE INFRA)',
#   'zakariaa FODIL (LINKT)'],
#  'TECSPG-3204 - Advanced ASR 9000 Operation and Troubleshooting': ['Jean-Michel Dilly (Adista)'],
#  'DEVNET-2527 - Models management in Cisco NSO – NED migrations deep dive': ['Jeremy Dassonville (ALTITUDE INFRA)',
#   'Kevin Bourgeaux (ALTITUDE INFRA)',
#   'Romain CAMPOLI (Covage Infra)',
#   'Alexandre Bartoli (LINKT)'],
#  'TSCSPG-2010 - unknown': ['Jeremy Dassonville (ALTITUDE INFRA)'],
#  'LTRCRT-2157 - unknown': ['Gaetan PRECIGOUT (BRETAGNE TELECOM)'],
#  'BRKSEC-2044 - Secure Operations for an IPv6 Network': ['Gilles Friang (SEWAN)',
#   'Stanislas de Goriainoff (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'VR-1001 - unknown': ['hanane grini (LINKT)'],
#  'ADD-3127 - unknown': ['Johan REMY (Adista)', 'Laurent DEVAI (Axione)'],
#  'DEVNET-1487 - Intro to Kubernetes': ['Bastien Fine (Adista)'],
#  'DEVNET-2628 - Headaches from YANG Models?  Using YANG Suite to Automate and Validate your Journey to Programmability': ['Nicolas Turpault (BRETAGNE TELECOM)'],
#  'BRKENT-3412 - How to Optimize SaaS Applications using Cisco SD-WAN ': ['Jean-Paul Blaisonneau (Axione)',
#   'Mathieu Bonnin (Axione)'],
#  'BRKOPT-1005 - High Value Wavelength / Private Line Services – Understanding the Customer and Provider Perspective': ['Nicolas Turpault (BRETAGNE TELECOM)',
#   'Thomas Delaby (France-IX)',
#   'Vittorio Mihailescu (France-IX)',
#   'hanane grini (LINKT)'],
#  'BRKOPS-2068 - Modern Switching Operations with Cisco DNA Center': ['Gilles Friang (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'PSOIOT-1004 - Digitize and Secure Your Industrial Operations with Cloud-native Management  ': ['Frederic Faraux (Claranet)'],
#  'BRKSEC-3320 - Demystifying TLS Decryption and Encrypted Visibility Engine on Cisco Secure Firewall Threat Defense': ['Mathieu Bonnin (Axione)'],
#  'BRKOPS-2312 - Do’s and Don’ts in Network Test Automation': ['Jean-Michel Dilly (Adista)',
#   'Jeremy Dassonville (ALTITUDE INFRA)',
#   'Pestka Fabien (ALTITUDE INFRA)',
#   'Pierre Etancelin (ALTITUDE INFRA)',
#   'Laurent DEVAI (Axione)',
#   'Romain CAMPOLI (Covage Infra)',
#   'Alexandre Bartoli (LINKT)'],
#  'CSSSPG-2572 - unknown': ['Jeremy Dassonville (ALTITUDE INFRA)',
#   'Romain CAMPOLI (Covage Infra)'],
#  'LABOPS-1507 - unknown': ['Alexandre Bartoli (LINKT)'],
#  'DEVNET-1700 - The Good, The Bad, and The Ugly of Automation': ['Mathieu Bonnin (Axione)'],
#  'BRKSPG-2835 - EVPN IOS-XR Deep Dive for Service Providers and Data Center ': ['Jeremy Dassonville (ALTITUDE INFRA)',
#   'wissal berrada (ALTITUDE INFRA)',
#   'Jérémy Pernes (ALTITUDE INFRA)',
#   'Pestka Fabien (ALTITUDE INFRA)',
#   'Frederic OSMONT (ALTITUDE INFRA)',
#   'Pierre Etancelin (ALTITUDE INFRA)',
#   'Jean-Paul Blaisonneau (Axione)',
#   'Laurent DEVAI (Axione)',
#   'Mathieu Bonnin (Axione)',
#   'Romain CAMPOLI (Covage Infra)',
#   'Thomas Delaby (France-IX)',
#   'Matthieu DURIEUX (InterCloud)',
#   'Gilles Friang (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'BRKOPT-2578 - Routed Optical Networking Deployment Use Cases': ['wissal berrada (ALTITUDE INFRA)',
#   'Jérémy Pernes (ALTITUDE INFRA)',
#   'Gaetan PRECIGOUT (BRETAGNE TELECOM)',
#   'Nicolas Turpault (BRETAGNE TELECOM)',
#   'Jean-Christophe DERIAN (Claranet)',
#   'hanane grini (LINKT)',
#   'Gilles Friang (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'LTRMPL-2208 - unknown': ['Nicolas Turpault (BRETAGNE TELECOM)'],
#  'DEVNET-2094 - Introduction to Continuous Development (CICD) with GitLab': ['Rodrigue ESTEVE (Axione)'],
#  'CISCOU-2672 - unknown': ['zakariaa FODIL (LINKT)'],
#  'DEVWKS-1176 - Intro to Python': ['Bastien Fine (Adista)'],
#  'LTRMPL-2116 - unknown': ['Johan REMY (Adista)',
#   'hanane grini (LINKT)',
#   'zakariaa FODIL (LINKT)'],
#  'BRKSPG-2028 - Management of IP+Optical Networks Using an SDN Controller Architecture ': ['Rodrigue ESTEVE (Axione)',
#   'Romain CAMPOLI (Covage Infra)'],
#  'PSOSEC-1213 - The Evolution of Ransomware': ['Vittorio Mihailescu (France-IX)',
#   'barnabe Louvet (LINKT)'],
#  'BRKDCN-3982 - ACI L4-L7 Policy-Based Redirect (PBR) Deep Dive and Tips': ['Frederic Faraux (Claranet)'],
#  'LTROPS-2835 - unknown': ['Johan REMY (Adista)',
#   'Kevin Bourgeaux (ALTITUDE INFRA)',
#   'Pestka Fabien (ALTITUDE INFRA)',
#   'Pierre Etancelin (ALTITUDE INFRA)'],
#  "DEVNET-2273 - Model-Driven DevOps - The Enterprise Automation Framework You've Been Looking For!": ['Kevin Bourgeaux (ALTITUDE INFRA)',
#   'Rodrigue ESTEVE (Axione)'],
#  'BRKSPG-3050 - Synchronizing 5G Mobile Networks': ['Frederic OSMONT (ALTITUDE INFRA)'],
#  'BRKSEC-3129 - Public Key Cryptography - from RSA and EC to post-quantum': ['Thomas Delaby (France-IX)'],
#  'BRKSPG-2029 - Designing Routed Optical Networks – IP/MPLS Considerations': ['Bastien Fine (Adista)',
#   'Rodrigue ESTEVE (Axione)',
#   'Vittorio Mihailescu (France-IX)',
#   'hanane grini (LINKT)',
#   'zakariaa FODIL (LINKT)'],
#  'BRKPAR-3304 - unknown': ['Kevin Bourgeaux (ALTITUDE INFRA)',
#   'Frederic Faraux (Claranet)'],
#  'DEVWKS-2919 - Real-world API Attacks, and How to Protect Your Cloud-native Apps': ['Frederic Faraux (Claranet)'],
#  'PSOMS-1330 - AIOps: the Next Evolution of IT Operations': ['Rodrigue ESTEVE (Axione)'],
#  'BRKOPS-2431 - Network Automation in Theory and Practice. A journey from YANG modeling to NETCONF, RESTCONF, gNMI and CLI management protocols': ['Thomas Delaby (France-IX)',
#   'zakariaa FODIL (LINKT)'],
#  'BRKSEC-2051 - The Evolution of DNS Security': ['Vittorio Mihailescu (France-IX)'],
#  'BRKOPS-2176 - Real Time Saving on Network Fault Incidents using Power of Automation': ['Alexandre Bartoli (LINKT)'],
#  'TECSPG-2435 - Routed Optical Networking Technical Deep Dive': ['Johan REMY (Adista)'],
#  'BRKOPS-2376 - Expand your Automation Journey with new Cisco NSO Use Cases and Features': ['Jean-Michel Dilly (Adista)',
#   'Alexandre Bartoli (LINKT)'],
#  'BRKDCN-1601 - Introduction to ACI': ['Jean-Christophe DERIAN (Claranet)'],
#  'BRKSPG-3624 - Troubleshooting Segment Routing': ['Jean-Michel Dilly (Adista)',
#   'Laurent DEVAI (Axione)',
#   'Alexandre Bartoli (LINKT)'],
#  'BRKSEC-2644 - Secure Access Service Edge - From Home to the Office with Cisco SASE!': ['Johan REMY (Adista)'],
#  'BRKPAR-2906 - unknown': ['zakariaa FODIL (LINKT)'],
#  'BRKSPG-2031 - Deploying XR Programmability in Production Networks': ['Jean-Michel Dilly (Adista)',
#   'Gaetan PRECIGOUT (BRETAGNE TELECOM)',
#   'Nicolas Turpault (BRETAGNE TELECOM)',
#   'Thomas Delaby (France-IX)',
#   'Vittorio Mihailescu (France-IX)',
#   'Gilles Friang (SEWAN)',
#   'Stanislas de Goriainoff (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'TECIPV-2000 - IPv6 on the Host': ['Thomas Delaby (France-IX)',
#   'Vittorio Mihailescu (France-IX)'],
#  'LTRSEC-2272 - unknown': ['Johan REMY (Adista)'],
#  "BRKIPV-3340 - Hitchhiker's Guide to IPv6": ['Alexandre Bartoli (LINKT)'],
#  'DEVLIT-2785 - Getting Started with IaC and Terraform': ['Laurent DEVAI (Axione)'],
#  'DEVNET-2459 - Stop the Chaos, Organize your Network with NSO and Netbox': ['Romain CAMPOLI (Covage Infra)'],
#  'BRKDCN-2689 - Streaming Telemetry on Cisco NX-OS': ['Jean-Michel Dilly (Adista)',
#   'Vittorio Mihailescu (France-IX)'],
#  'BRKDCN-1613 - VXLAN or GENEVE what is a better choice for your Data Center': ['Frederic Faraux (Claranet)'],
#  'BRKOPS-2136 - Experience Telemetry - Driving Insights and Actions': ['Jeremy Dassonville (ALTITUDE INFRA)',
#   'Laurent DEVAI (Axione)',
#   'Mathieu Bonnin (Axione)',
#   'Romain CAMPOLI (Covage Infra)',
#   'Vittorio Mihailescu (France-IX)',
#   'Gilles Friang (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'LTRSP-2837 - unknown': ['Jeremy Dassonville (ALTITUDE INFRA)',
#   'Romain CAMPOLI (Covage Infra)'],
#  'BRKMPL-1123 - Multicast Segment Routing & Traffic Engineering ': ['Jean-Michel Dilly (Adista)',
#   'wissal berrada (ALTITUDE INFRA)',
#   'Jérémy Pernes (ALTITUDE INFRA)',
#   'Frederic OSMONT (ALTITUDE INFRA)',
#   'Jean-Paul Blaisonneau (Axione)',
#   'Jean-Christophe DERIAN (Claranet)'],
#  'BRKOPS-2040 - CiscoLive:  Brought To You By Cisco NSO and Cisco Modeling Labs': ['Alexandre Bartoli (LINKT)'],
#  'BRKSEC-2128 - SASE the SOCs New Best Friend': ['Stanislas de Goriainoff (SEWAN)'],
#  'BRKSEC-2678 - DDoS Mitigation: Introducing Radware Deployment on Firepower Appliances': ['Jean-Christophe DERIAN (Claranet)',
#   'barnabe Louvet (LINKT)'],
#  'BRKENT-2423 - SD-WAN From Design to Reality': ['Jean-Paul Blaisonneau (Axione)'],
#  "BRKSEC-2438 - Solving Today's Challenges with the Newest Features in Cisco Umbrella": ['Johan REMY (Adista)'],
#  'BRKDCN-2667 - Simple Leaf/Spine with a touch of TOR  - Network Designs for the Modern Data Center': ['Jean-Christophe DERIAN (Claranet)'],
#  'CSSSPG-1702 - unknown': ['Jean-Christophe DERIAN (Claranet)'],
#  'LTRSPG-2161 - unknown': ['Alexandre Bartoli (LINKT)'],
#  'IMP-2741 - unknown': ['barnabe Louvet (LINKT)'],
#  'BRKARC-2885 - Cisco Catalyst 8500 Series Edge Platform Deep Dive': ['Bastien Fine (Adista)'],
#  'DEVWKS-2300 - Health Monitoring an Integral Part of the Lifecycle of a Network Service': ['Frederic Faraux (Claranet)'],
#  'IBOSPG-2001 - unknown': ['Johan REMY (Adista)'],
#  'BRKDCN-2913 - VXLAN BGP EVPN Multi-Site': ['Gilles Friang (SEWAN)',
#   'Stanislas de Goriainoff (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'BRKDCN-2929 - Simple VXLAN/EVPN Fabric setup with Nexus Dashboard': ['Laurent DEVAI (Axione)',
#   'Frederic Faraux (Claranet)'],
#  'LTROPS-2409 - unknown': ['Bastien Fine (Adista)'],
#  'BRKPAR-3078 - unknown': ['Frederic Faraux (Claranet)'],
#  'BRKPAR-2911 - unknown': ['Jean-Paul Blaisonneau (Axione)'],
#  'TSCSPG-2011 - unknown': ['Jean-Michel Dilly (Adista)'],
#  'BRKSPM-2024 - The New, Encrypted Protocol Stack Taking over the Internet and How to Deal with It': ['Jean-Paul Blaisonneau (Axione)'],
#  'ITLGEN-2103 - unknown': ['Gilles Friang (SEWAN)',
#   'Stanislas de Goriainoff (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'BRKMPL-2131 - Deploying VPNs Over Segment Routed Networks Made Easy': ['Jean-Paul Blaisonneau (Axione)',
#   'Thomas Delaby (France-IX)',
#   'hanane grini (LINKT)'],
#  'LTRSP-3145 - unknown': ['wissal berrada (ALTITUDE INFRA)',
#   'Jérémy Pernes (ALTITUDE INFRA)',
#   'Frederic OSMONT (ALTITUDE INFRA)'],
#  'BRKDCN-2906 - Introduction to Infrastructure as Code for ACI with Ansible and Terraform': ['Alexandre Bartoli (LINKT)'],
#  'BRKOPS-2138 - Low Earth Orbit Satellites - Exploring Unique Real-World Deployments': ['Jean-Christophe DERIAN (Claranet)'],
#  "BRKENT-1616 - IPv6 - What Do you Mean there isn't a Broadcast?": ['Jean-Christophe DERIAN (Claranet)'],
#  'LABTRS-2391 - unknown': ['zakariaa FODIL (LINKT)'],
#  'TSCTRS-2007 - unknown': ['Vittorio Mihailescu (France-IX)'],
#  'IBOOPT-2000 - unknown': ['Laurent DEVAI (Axione)'],
#  "BRKSEC-2354 - Automating Security: Just Because You Can, Doesn't Mean You Should": ['Jean-Christophe DERIAN (Claranet)'],
#  'DEVWKS-2818 - Provision Infrastructure Solutions at Cloud Scale with the Terraform Provider for Cisco Intersight': ['Frederic Faraux (Claranet)'],
#  'BRKSPG-2944 - Cisco 8000 Technical Update: Powered by Silicon One & IOS XR7 ': ['Jean-Paul Blaisonneau (Axione)',
#   'Mathieu Bonnin (Axione)',
#   'Thomas Delaby (France-IX)',
#   'Vittorio Mihailescu (France-IX)',
#   'Gilles Friang (SEWAN)',
#   'Stanislas de Goriainoff (SEWAN)',
#   'olivier Vernadal (SEWAN)',
#   'Olivier MANSALIER (Adista)'],
#  'PSOCOL-2311 - Webex achieves full Data Residency in EU': ['Stanislas de Goriainoff (SEWAN)'],
#  'BRKDCN-2671 - Connecting On-prem network to Public Cloud using Nexus Hybrid Cloud': ['Frederic Faraux (Claranet)'],
#  'BRKOPT-2130 - The Journey towards Routed Optical Networking': ['Frederic OSMONT (ALTITUDE INFRA)'],
#  "BRKSEC-1240 - If you don't have a Security Reference Architecture, you must get one!": ['Kevin Bourgeaux (ALTITUDE INFRA)'],
#  'DEVNET-2084 - Get Started with the Hyperflex REST API': ['Jean-Michel Dilly (Adista)',
#   'Nicolas Turpault (BRETAGNE TELECOM)'],
#  'BRKPAR-2965 - unknown': ['barnabe Louvet (LINKT)'],
#  'BRKIOT-2585 - Deployment of Cisco Catalyst Industrial Routers in Public and Private Cellular Infrastructures': ['barnabe Louvet (LINKT)'],
#  'CISCOU-2664 - unknown': ['Jean-Michel Dilly (Adista)',
#   'Kevin Bourgeaux (ALTITUDE INFRA)'],
#  'BRKTRS-2811 - Overview of Packet Capturing Tools in Cisco Switches and Routers': ['wissal berrada (ALTITUDE INFRA)',
#   'Jérémy Pernes (ALTITUDE INFRA)',
#   'Pestka Fabien (ALTITUDE INFRA)',
#   'Frederic OSMONT (ALTITUDE INFRA)',
#   'Pierre Etancelin (ALTITUDE INFRA)',
#   'Gaetan PRECIGOUT (BRETAGNE TELECOM)',
#   'Nicolas Turpault (BRETAGNE TELECOM)',
#   'hanane grini (LINKT)',
#   'zakariaa FODIL (LINKT)'],
#  'BRKCLD-2365 - But... why do I need a Service Mesh?': ['Rodrigue ESTEVE (Axione)'],
#  'BRKDCN-1901 - Introduction to VXLAN: The Future Path of Your Datacenter': ['Jean-Christophe DERIAN (Claranet)',
#   'Thomas Delaby (France-IX)'],
#  'BRKSP-2551 - Introduction to Segment Routing': ['Bastien Fine (Adista)',
#   'Jeremy Dassonville (ALTITUDE INFRA)',
#   'Kevin Bourgeaux (ALTITUDE INFRA)',
#   'wissal berrada (ALTITUDE INFRA)',
#   'Jérémy Pernes (ALTITUDE INFRA)',
#   'Pestka Fabien (ALTITUDE INFRA)',
#   'Frederic OSMONT (ALTITUDE INFRA)',
#   'Pierre Etancelin (ALTITUDE INFRA)',
#   'Mathieu Bonnin (Axione)',
#   'Romain CAMPOLI (Covage Infra)',
#   'Thomas Delaby (France-IX)',
#   'Vittorio Mihailescu (France-IX)',
#   'Matthieu DURIEUX (InterCloud)',
#   'hanane grini (LINKT)',
#   'Gilles Friang (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  "BRKENT-2109 - Let's Deploy IPv6 NOW": ['hanane grini (LINKT)',
#   'zakariaa FODIL (LINKT)'],
#  'CISCOU-2666 - unknown': ['zakariaa FODIL (LINKT)',
#   'Olivier MANSALIER (Adista)'],
#  'BRKDCN-2621 - Architecting Hybrid Multi-Cloud Infrastructures': ['Alexandre Bartoli (LINKT)'],
#  'DEVNET-1460 - Jupyter Notebooks + XR for Modern Learning Process ': ['Laurent DEVAI (Axione)'],
#  'BRKIPV-3134 - IPv6 Security in the Local Area with First Hop Security': ['Jean-Christophe DERIAN (Claranet)',
#   'Vittorio Mihailescu (France-IX)'],
#  'BRKENS-3096 - Migrating Classical Enterprise Campus Networks to VXLAN EVPN Based Networks ': ['Jean-Christophe DERIAN (Claranet)',
#   'Alexandre Bartoli (LINKT)',
#   'Gilles Friang (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  "PSOGEN-1040 - Efficiency Meets Innovation: An Overview of Cisco's Enterprise Agreement 3.0 and How it Benefits your Business": ['Jean-Christophe DERIAN (Claranet)'],
#  'DEVNET-1849 - Network Automation - Start Here': ['Bastien Fine (Adista)'],
#  'BRKAPP-1011 - Deliver Flawless Digital Experiences in an Internet and Hybrid Cloud World: End-to-End Visibility from AppDynamics and ThousandEyes': ['Jean-Michel Dilly (Adista)'],
#  'BRKSPG-2343 - Internet for the Future: Journey to the Next Generation SP Architecture and Operating Model': ['Jeremy Dassonville (ALTITUDE INFRA)',
#   'Romain CAMPOLI (Covage Infra)'],
#  'BRKDCN-3638 - Overlay Multicast in VXLAN EVPN (Tenant Routed Multicast - TRM)': ['Laurent DEVAI (Axione)',
#   'Frederic Faraux (Claranet)'],
#  'BRKSEC-3058 - Route based VPNs with Cisco Secure Firewall': ['Jean-Christophe DERIAN (Claranet)'],
#  'BRKSPG-2868 - Building Trustworthy Critical Infrastructure with IOS-XR Platforms': ['Frederic Faraux (Claranet)',
#   'Jean-Christophe DERIAN (Claranet)'],
#  'BRKDEV-1533 - Kubernetes and you!': ['Gaetan PRECIGOUT (BRETAGNE TELECOM)',
#   'Jean-Christophe DERIAN (Claranet)'],
#  'BRKENT-2060 - Cisco SD-WAN Cloud OnRamp for Multicloud - from Connectivity to Application Integration': ['Jean-Paul Blaisonneau (Axione)',
#   'Mathieu Bonnin (Axione)'],
#  'DEVNET-2158 - API Middle-tier for Dummies, or How to Make your UI Developers Happy by Stitching all your APIs Together.': ['Gaetan PRECIGOUT (BRETAGNE TELECOM)'],
#  'BRKSEC-2238 - Getting SASE with Umbrella and Meraki – Understand best practices for simple and flexible integrations between Meraki and Umbrella': ['Johan REMY (Adista)'],
#  'LTRIPV-2130 - unknown': ['Jean-Michel Dilly (Adista)'],
#  'BRKDEV-2985 - Config-as-Code – Maintain and deploy Cisco DNAC templates in a CICD Pipeline': ['Kevin Bourgeaux (ALTITUDE INFRA)'],
#  'BRKSEC-2287 - Who is Behind the Umbrella? A View on User Authentication with Cisco Umbrella': ['Jean-Paul Blaisonneau (Axione)'],
#  'PSOSEC-1211 - Cisco Secure Firewall: Driving Security Resilience Across a Hybrid and Multicloud World': ['Kevin Bourgeaux (ALTITUDE INFRA)'],
#  'DEVNET-1850 - Introducing Webex Connect and CPaaS APIs': ['Stanislas de Goriainoff (SEWAN)'],
#  'BRKDCN-2999 - Multi-Tier Fabrics - Network Designs for the Modern Data Center': ['Jean-Christophe DERIAN (Claranet)',
#   'Vittorio Mihailescu (France-IX)',
#   'Gilles Friang (SEWAN)',
#   'olivier Vernadal (SEWAN)'],
#  'BRKARC-2881 - Fixed Platform ISR1000 and ISR1100 Series Deep Dive': ['Jean-Paul Blaisonneau (Axione)',
#   'Mathieu Bonnin (Axione)',
#   'zakariaa FODIL (LINKT)'],
#  'BRKSPG-2473 - EVPN Troubleshooting and Debugging': ['Jean-Michel Dilly (Adista)',
#   'Johan REMY (Adista)',
#   'Frederic Faraux (Claranet)'],
#  'DEVNET-2405 - CrossWork APIs Zero to Hero': ['Gaetan PRECIGOUT (BRETAGNE TELECOM)'],
#  'CISCOU-2659 - unknown': ['Laurent DEVAI (Axione)'],
#  'BRKIOT-2544 - Future-ready Shopfloor Architecture and How You Can Get to It – Step by Step': ['Rodrigue ESTEVE (Axione)'],
#  'BRKDCN-2983 - Kubernetes (K8s) Infrastructure Connectivity  - Network Designs for the Modern Data Center': ['Alexandre Bartoli (LINKT)'],
#  'BRKOPT-2699 - Optics is Heading Into the Terabit Era - What You Need to Know!': ['Jean-Paul Blaisonneau (Axione)',
#   'Thomas Delaby (France-IX)'],
#  'PSOENT-1794 - Deploying a Unified SASE Architecture: Cisco+ Secure Connect Options': ['barnabe Louvet (LINKT)'],
#  'BRKDCN-2924 - Data Center Network Design for Media and Entertainment Industry': ['Jean-Christophe DERIAN (Claranet)'],
#  'BRKEWN-2284 - Becoming a Wi-Fi Guest star: Better Practices for Guest Networks on Cisco Catalyst Wireless': ['Thomas Delaby (France-IX)'],
#  'BRKSEC-2172 - Peeling an Onion: A Short Travel into the Darknet': ['Rodrigue ESTEVE (Axione)'],
#  'BRKNWT-2205 - Edge-Native: The New Paradigm for Operating and Developing Edge Apps': ['Rodrigue ESTEVE (Axione)'],
#  'ITLGEN-2213 - unknown': ['Mathieu Bonnin (Axione)'],
#  'TSCTRS-2004 - unknown': ['Frederic Faraux (Claranet)'],
#  'BRKSP-2637 - Network Automation with Routed Optical Networking (RON) Architecture': ['Jean-Michel Dilly (Adista)',
#   'Kevin Bourgeaux (ALTITUDE INFRA)',
#   'Pestka Fabien (ALTITUDE INFRA)',
#   'Pierre Etancelin (ALTITUDE INFRA)',
#   'Rodrigue ESTEVE (Axione)',
#   'Nicolas Turpault (BRETAGNE TELECOM)',
#   'hanane grini (LINKT)',
#   'zakariaa FODIL (LINKT)'],
#  'IBOCX-1101 - unknown': ['Pestka Fabien (ALTITUDE INFRA)'],
#  'LTRATO-2001 - unknown': ['Johan REMY (Adista)'],
#  'BRKSPM-2386 - Getting Ready for Private 5G Deployments ': ['Rodrigue ESTEVE (Axione)',
#   'barnabe Louvet (LINKT)',
#   'hanane grini (LINKT)',
#   'zakariaa FODIL (LINKT)'],
#  'BRKSP-2133 - SP Service Creation and Edge Transformation': ['Pestka Fabien (ALTITUDE INFRA)',
#   'Pierre Etancelin (ALTITUDE INFRA)',
#   'Mathieu Bonnin (Axione)',
#   'Rodrigue ESTEVE (Axione)',
#   'Gilles Friang (SEWAN)',
#   'Stanislas de Goriainoff (SEWAN)',
#   'olivier Vernadal (SEWAN)']}

# %%
df_final = pd.DataFrame({'Sessions':[], 'Customers':[]})

df_final
# Out:
# Empty DataFrame
# Columns: [Sessions, Customers]
# Index: []

# %%
for key, value in sessions_customers_dict.items():
    new_row = pd.DataFrame({'Sessions': [key], 'Customers': [', '.join(value)]})

    df_final = pd.concat([df_final, new_row], ignore_index=True)

df_final
# Out:
#                                               Sessions  \
# 0    BRKOPT-2837 - Scaling Enterprise Networks with...
# 1    BRKDCN-2938 - Intersight Managed Mode (IMM) fo...
# 2                               BYODCRT-2464 - unknown
# 3       BRKNWT-2210 - Predicting Networks are THERE !!
# 4    BRKMER-2399 - Meraki Wireless from a Troublesh...
# ..                                                 ...
# 155  BRKSP-2637 - Network Automation with Routed Op...
# 156                               IBOCX-1101 - unknown
# 157                              LTRATO-2001 - unknown
# 158  BRKSPM-2386 - Getting Ready for Private 5G Dep...
# 159  BRKSP-2133 - SP Service Creation and Edge Tran...
#
#                                              Customers
# 0                            Thomas Delaby (France-IX)
# 1                                Bastien Fine (Adista)
# 2                               zakariaa FODIL (LINKT)
# 3    Mathieu Bonnin (Axione), Frederic Faraux (Clar...
# 4                      Stanislas de Goriainoff (SEWAN)
# ..                                                 ...
# 155  Jean-Michel Dilly (Adista), Kevin Bourgeaux (A...
# 156                     Pestka Fabien (ALTITUDE INFRA)
# 157                                Johan REMY (Adista)
# 158  Rodrigue ESTEVE (Axione), barnabe Louvet (LINK...
# 159  Pestka Fabien (ALTITUDE INFRA), Pierre Etancel...
#
# [160 rows x 2 columns]

# %%
with pd.ExcelWriter('customers_sessions_output.xlsx') as writer:
    df_final.to_excel(writer, index=False)
